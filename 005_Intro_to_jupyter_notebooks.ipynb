# %% [markdown]
# ![tbAnalyst Logo](https://1drv.ms/i/c/d3c2126aa874b496/IQR2Wuv8Pbs5RrnMKvbnNe8DAVom3Dq4iDPelXsLDPx-fNo?width=200&height=100)

# %% [markdown]
# # Introduction to Juptwe Notebooks

# %% [markdown]
# Use `Shift + Enter` to run a cell and select the cell below it.

# %%
2+5
# Out:
# 7

# %% [markdown]
# Use `Ctrl + Enter` to run a cell and keep that cell selectd.

# %%
2+5
# Out:
# 7

# %%
2+5
# Out:
# 7

# %%
2+5
# Out:
# 7

# %%
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# Note: if you are not printing to the screen, then only the last expression\code line will be displayed as an output

# %%
1+3
2+7
# Out:
# 9

# %% [markdown]
# Node: If you use print(), then this print statement will be displayed.

# %%
print(1+3)
print(2+7)
# Out:
# 4
# 9

# %% [markdown]
# Note: If you use both (print() and an expression, then you will get the print statement displayed and the expression evaluation as an output

# %%
print(1+3)
2+7
# Out:
# 4
# 9

# %%
print("Hi")
# Out:
# Hi

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %% [markdown]
# x

# %% [markdown]
# Using terminal commands

# %%
# !dir
# Out:
#  Volume in drive I is New Volume
#  Volume Serial Number is F207-5A32
#
#  Directory of I:\notebooks\python
#
# 06/29/2025  09:35 AM    <DIR>          .
# 06/29/2025  09:35 AM    <DIR>          ..
# 06/29/2025  09:22 AM    <DIR>          .ipynb_checkpoints
# 06/28/2025  05:33 PM             6,054 Augmented Assignment.ipynb
# 06/22/2025  11:18 AM             8,793 comments.ipynb
# 06/18/2025  01:44 PM             4,217 Data Types Overview.ipynb
# 06/14/2025  07:51 AM            10,220 Exercise_Intro_to_notebooks.ipynb
# 06/29/2025  09:22 AM    <DIR>          files
# 06/09/2025  11:06 PM           101,938 image.jpg
# 06/22/2025  12:56 PM             5,528 indentation.ipynb
# 06/29/2025  09:35 AM            10,013 intro_to_jupyter_notebooks.ipynb
# 06/13/2025  09:27 PM            10,263 Markdown.ipynb
# 06/28/2025  03:42 PM             9,949 math functions.ipynb
# 06/26/2025  04:09 PM            17,293 Numbers I.ipynb
# 06/26/2025  03:13 PM            16,536 Numbers.ipynb
# ...

# %%
# !copy ..\baby.mp4 .
# Out:
#         1 file(s) copied.

# %%
# !dir
# Out:
#  Volume in drive I is New Volume
#  Volume Serial Number is F207-5A32
#
#  Directory of I:\notebooks\python
#
# 06/29/2025  09:36 AM    <DIR>          .
# 06/29/2025  09:35 AM    <DIR>          ..
# 06/29/2025  09:22 AM    <DIR>          .ipynb_checkpoints
# 06/28/2025  05:33 PM             6,054 Augmented Assignment.ipynb
# 04/05/2024  10:47 AM         4,046,090 baby.mp4
# 06/22/2025  11:18 AM             8,793 comments.ipynb
# 06/18/2025  01:44 PM             4,217 Data Types Overview.ipynb
# 06/14/2025  07:51 AM            10,220 Exercise_Intro_to_notebooks.ipynb
# 06/29/2025  09:22 AM    <DIR>          files
# 06/09/2025  11:06 PM           101,938 image.jpg
# 06/22/2025  12:56 PM             5,528 indentation.ipynb
# 06/29/2025  09:35 AM            10,013 intro_to_jupyter_notebooks.ipynb
# 06/13/2025  09:27 PM            10,263 Markdown.ipynb
# 06/28/2025  03:42 PM             9,949 math functions.ipynb
# 06/26/2025  04:09 PM            17,293 Numbers I.ipynb
# ...

# %% [markdown]
# Note: Python is case-sensitive language, make sure to type the specific casing (uppercase or lowercase).

# %%
from ipython.display import Video
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from ipython.display import Video
#
# ModuleNotFoundError: No module named 'ipython'

# %%
from IPython.display import video
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from IPython.display import video
#
# ImportError: cannot import name 'video' from 'IPython.display' (C:\Users\tbAnalyst\anaconda3\Lib\site-packages\IPython\display.py)

# %% [markdown]
# You can play a video Directly inside your jupyter notebook

# %%
from IPython.display import Video

# %%
Video("baby.mp4", width=720, height=480)
# Out:
# <video src="baby.mp4" controls  width="720"  height="480">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# You can display images inside your jupyter notebook file.

# %% [markdown]
# Use img html tag in a text cell to display an image

# %% [markdown]
# <img src="image.png">

# %% [markdown]
# Combine CSS tags with the html img tag.

# %% [markdown]
# <img src="image.png" style="width: 200px; height:100px;">

# %% [markdown]
# You can use markdown syntax to display the image

# %% [markdown]
# ![](image.png)
